# %% [markdown]
# <a href="https://colab.research.google.com/github/nagarjuna-32/python-practice/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pages = list(map(int, input().split()))

for page in pages:
    if page > 300:
        print(page, end=" ")
